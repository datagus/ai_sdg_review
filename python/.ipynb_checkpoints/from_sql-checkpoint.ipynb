# %%
import pandas as pd
import json
from pybliometrics.scopus import AbstractRetrieval, AuthorRetrieval, AffiliationRetrieval
import warnings
import datetime
import sqlalchemy

# %%
## Load configuration from json file
con_file = open("config.json")
config = json.load(con_file)
con_file.close()

# %%
schema = config["schema"]
host = config["host"]
user = config["user"]
password = config["password"]
port = config["port"]

connection_string = f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'
connection_string
# Out:
# 'mysql+pymysql://root:centermethods2024$@127.0.0.1:3306/ai_sdgs'

# %%
articles_df = pd.read_sql("articles", con=connection_string)
article_type_df = pd.read_sql("type_of_article", con=connection_string)
art_alg_df = pd.read_sql("articles_algorithms", con=connection_string)
algorithms_df = pd.read_sql("algorithms_list", con=connection_string)
groups_df = pd.read_sql("clusters", con=connection_string)

# %%
df1 = pd.merge(art_alg_df, groups_df, on='eid', how='inner')

# %%
df2 = pd.merge(df1, articles_df, on='eid', how='inner')

# %%
df2.loc[df2["algorithms"].isin(["lstm", "k-means", "extreme learning machine"]),]
# Out:
#                     eid algorithms  \
# 291  2-s2.0-85113985918    k-means
# 292  2-s2.0-85136500537    k-means
# 293  2-s2.0-85137738728    k-means
# 294  2-s2.0-85150899019    k-means
# 295  2-s2.0-85171645006    k-means
# 329  2-s2.0-85057537994       lstm
# 330  2-s2.0-85082475744       lstm
# 331  2-s2.0-85088034777       lstm
# 332  2-s2.0-85088373071       lstm
# 333  2-s2.0-85107394966       lstm
# 334  2-s2.0-85108373363       lstm
# 335  2-s2.0-85108591812       lstm
# 336  2-s2.0-85117732239       lstm
# 337  2-s2.0-85141839246       lstm
# 338  2-s2.0-85144007803       lstm
# 339  2-s2.0-85151629524       lstm
# 340  2-s2.0-85166251581       lstm
# 341  2-s2.0-85174918556       lstm
# 342  2-s2.0-85180647853       lstm
#
#                                                  words cluster_number  \
# 291  camera, pixel, detection, image, localization,...              5
# 292  manufacturing, business, chain, competitivenes...              7
# 293  camera, pixel, detection, image, localization,...              5
# 294  camera, pixel, detection, image, localization,...              5
# 295  care, health, patient, healthcare, hospital, p...              1
# 329  vector, feature, prediction, accuracy, forecas...              3
# 330  river, rainfall, hydrology, water, square, bas...              4
# 331  river, rainfall, hydrology, water, square, bas...              4
# 332  vector, feature, prediction, accuracy, forecas...              3
# 333  vector, feature, prediction, accuracy, forecas...              3
# 334  energy, consumption, battery, power, design, c...              6
# 335  river, rainfall, hydrology, water, square, bas...              4
# 336  energy, consumption, battery, power, design, c...              6
# 337  vector, feature, prediction, accuracy, forecas...              3
# 338  land, soil, conservation, vegetation, crop, co...              2
# 339  river, rainfall, hydrology, water, square, bas...              4
# 340  land, soil, conservation, vegetation, crop, co...              2
# 341  vector, feature, prediction, accuracy, forecas...              3
# 342  river, rainfall, hydrology, water, square, bas...              4
#
#        cluster_name                                       article_file  \
# 291  remote sensing                         6_e_2-s2.0-85113985918.txt
# 292        industry       9_e_Arunmozhi M._2022_2-s2.0-85136500537.txt
# 293  remote sensing             14_e_Mbani_2022_2-s2.0-85137738728.txt
# 294  remote sensing             2_e_Waheed_2023_2-s2.0-85150899019.txt
# 295      healthcare               5_e_Deng_2023_2-s2.0-85171645006.txt
# 329     forecasting               12_e_Yan_2018_2-s2.0-85057537994.txt
# 330           water                         6_e_2-s2.0-85082475744.txt
# 331           water                         6_e_2-s2.0-85088034777.txt
# 332     forecasting     11_e_Schürholz D._2020_2-s2.0-85088373071.txt
# 333     forecasting         12_e_Codeluppi_2021_2-s2.0-85107394966.txt
# 334    clean energy                         6_e_2-s2.0-85108373363.txt
# 335           water                         6_e_2-s2.0-85108591812.txt
# 336    clean energy        11_e_Singh S.K._2022_2-s2.0-85117732239.txt
# 337     forecasting         7_e_Ibrahim B._2022_2-s2.0-85141839246.txt
# 338      vegetation             15_e_Zafar_2023_2-s2.0-85144007803.txt
# 339           water         15_e_Yamaguchi_2023_2-s2.0-85151629524.txt
# 340      vegetation          13_e_Malik I._2023_2-s2.0-85166251581.txt
# 341     forecasting            13_e_Wei X._2023_2-s2.0-85174918556.txt
# 342           water  13_e_Akbari Osmavandani S._2023_2-s2.0-8518064...
#
#                                                  title  year_pub sdg  \
# 291  An innovative machine learning based framework...      2022   6
# 292  Application of blockchain and smart contracts ...      2022   9
# 293  Implementation of an automated workflow for im...      2022  14
# 294  A Mobile-Based System for Detecting Ginger Lea...      2023   2
# 295  AI-driven innovation in ethnic clothing design...      2023   5
# 329  Multi-step short-term power consumption foreca...      2018  12
# 330  Computation of evapotranspiration with artific...      2020   6
# 331  Genetic-algorithm-optimized sequential model f...      2020   6
# 332  Artificial intelligence-enabled context-aware ...      2020  11
# 333  Forecasting air temperature on edge devices wi...      2021  12
# 334  Improved water resource management framework f...      2021   6
# 335  Application of deep learning method for daily ...      2021   6
# 336  Blockchain-enabled Secure Framework for Energy...      2022  11
# 337  Machine Learning for Short-Term Load Forecasti...      2022   7
# 338  Fostering deep learning approaches to evaluate...      2023  15
# 339  Using Simple LSTM Models to Evaluate Effects o...      2023  15
# 340  Estimation of the Extent of the Vulnerability ...      2023  13
# 341  Research on carbon emission prediction and eco...      2023  13
# 342  Assessing the effectiveness of artificial inte...      2023  13
#
#                                                journal  cited_by  \
# 291                       Structural Health Monitoring        12
# 292  Transportation Research Part E: Logistics and ...        12
# 293                                 Scientific Reports         2
# 294                                    Future Internet         2
# 295                        Electronic Research Archive         0
# 329                                           Energies       127
# 330                     Applied Sciences (Switzerland)        37
# 331                       Sustainability (Switzerland)        47
# 332                      Journal of Cleaner Production        35
# 333                                            Sensors        17
# 334                             Environmental Research        23
# 335  International Journal of Sustainable Developme...        16
# 336                     Sustainable Cities and Society        31
# 337                                           Energies        21
# 338                              Ecological Indicators         3
# 339                                Water (Switzerland)         1
# 340                       Sustainability (Switzerland)         5
# 341                 Frontiers in Ecology and Evolution         0
# 342                                    Acta Geophysica         0
#
#                                doi  \
# 291      10.1177/14759217211040269
# 292      10.1016/j.tre.2022.102864
# 293     10.1038/s41598-022-19070-2
# 294             10.3390/fi15030086
# 295            10.3934/era.2023295
# 329             10.3390/en11113089
# 330            10.3390/app10051621
# 331             10.3390/su12135374
# 332  10.1016/j.jclepro.2020.121941
# 333              10.3390/s21123973
# 334   10.1016/j.envres.2021.111527
# 335          10.18280/IJSDP.160310
# 336      10.1016/j.scs.2021.103364
# 337             10.3390/en15218079
# 338  10.1016/j.ecolind.2022.109788
# 339              10.3390/w15061115
# 340            10.3390/su151411465
# 341      10.3389/fevo.2023.1270248
# 342     10.1007/s11600-023-01257-4
#
#                                                authors
# 291                                      Fan X.; Yu X.
# 292  Arunmozhi M.; Venkatesh V.G.; Arisian S.; Shi ...
# 293  Mbani B.; Schoening T.; Gazis I.-Z.; Koch R.; ...
# 294  Waheed H.; Akram W.; Islam S.U.; Hadi A.; Boud...
# 295                           Deng M.; Liu Y.; Chen L.
# 329  Yan K.; Wang X.; Du Y.; Jin N.; Huang H.; Zhou H.
# 330  Afzaal H.; Farooque A.A.; Abbas F.; Acharya B....
# 331  Stajkowski S.; Kumar D.; Samui P.; Bonakdari H...
# 332              Schürholz D.; Kubler S.; Zaslavsky A.
# 333                Codeluppi G.; Davoli L.; Ferrari G.
# 334  Ahmed S.S.; Bali R.; Khan H.; Mohamed H.I.; Sh...
# 335                             Latif S.D.; Ahmed A.N.
# 336                      Singh S.K.; Pan Y.; Park J.H.
# 337  Ibrahim B.; Rabelo L.; Gutierrez-Franco E.; Cl...
# 338  Zafar Z.; Sajid Mehmood M.; Shiyan Z.; Zubair ...
# 339                Yamaguchi T.; Miyamoto H.; Oishi T.
# 340  Malik I.; Ahmed M.; Gulzar Y.; Baba S.H.; Mir ...
# 341                                      Wei X.; Xu Y.
# 342  Akbari Osmavandani S.; Sharafati A.; Moghaddam...

# %%
df1 = pd.merge(articles_df, article_type_df, on='eid', how='inner')

# %%
df2 = pd.merge(df1, abstracts_df, on='eid', how='inner')

# %%
df3 = pd.merge(df2, art_alg_df, on='eid', how='inner')

# %%
df4 = pd.merge(df3, algorithms_df, on='algorithms', how='inner')

# %%
df5 = pd.merge(df4, alg_ai_df, on='algorithms', how='inner')

# %%
df6 = pd.merge(df5, aitype, on='ai_type', how='inner')

# %%
df7 = df6.loc[df6["article_type"] == "empirical",].reset_index(drop=True)

# %%
df7.loc[df7["ai_type"] == "various", ]
# Out:
#                     eid                                              title  \
# 3    2-s2.0-33751058457  Hybrid System for fouling control in biomass b...
# 20   2-s2.0-72649093786  A hybrid decision support system for sustainab...
# 96   2-s2.0-85048598058  Machine Learning-Augmented Propensity Score-Ad...
# 110  2-s2.0-85056204019  Forecasting energy consumption time series usi...
# 120  2-s2.0-85058120103  An integrated multicriteria analysis tool for ...
# 179  2-s2.0-85078363262  Leveraging artificial intelligence to improve ...
# 215  2-s2.0-85085638015  Artificial Intelligence-Aided Model Predictive...
# 311  2-s2.0-85104629628  Application of machine learning techniques in ...
# 429  2-s2.0-85118703265  Performance of machine learning methods in pre...
# 453  2-s2.0-85123355204  Deep learning models for improved reliability ...
# 538  2-s2.0-85138635414  What Do Twitter Users Think about Climate Chan...
# 678  2-s2.0-85168708436  Machine Learning Approaches for Forecasting th...
# 733  2-s2.0-85181176727  Does artificial intelligence (AI) reduce ecolo...
#
#      year_pub sdg                                            journal  \
# 3        2006   7  Engineering Applications of Artificial Intelli...
# 20       2010  12                               Energy and Buildings
# 96       2018   4                      BioMed Research International
# 110      2018  12                                             Energy
# 120      2018   6                                Water (Switzerland)
# 179      2019   3                                        IEEE Access
# 215      2020   7                                        IEEE Access
# 311      2021   9                       Sustainability (Switzerland)
# 429      2021   6                              Applied Water Science
# 453      2022  15                      Forest Ecology and Management
# 538      2022   5                      Weather, Climate, and Society
# 678      2023   2                          Agriculture (Switzerland)
# 733      2023  15  Environmental science and pollution research i...
#
#      cited_by                             doi  policy_recommendations  \
# 3          29  10.1016/j.engappai.2006.01.019                       0
# 20        287   10.1016/j.enbuild.2009.09.006                       0
# 96         37            10.1155/2018/5051289                       0
# 110       139    10.1016/j.energy.2018.09.144                       0
# 120        43               10.3390/w10121795                       0
# 179        22     10.1109/ACCESS.2019.2938265                       0
# 215        27     10.1109/ACCESS.2020.2994577                       0
# 311        48              10.3390/su13084120                       0
# 429       109      10.1007/s13201-021-01528-9                       0
# 453         7    10.1016/j.foreco.2022.120031                       0
# 538         3        10.1175/WCAS-D-21-0163.1                       0
# 678         1     10.3390/agriculture13081622                       0
# 733         0      10.1007/s11356-023-31076-5                       1
#
#     article_type                                         core_topic  \
# 3      empirical  Hybrid systems for biomass boiler fouling control
# 20     empirical                    Sustainable building renovation
# 96     empirical              AI in preventive cardiology education
# 110    empirical         Residential energy consumption forecasting
# 120    empirical                   Irrigation constraint evaluation
# 179    empirical               AI for voice disorder identification
# 215    empirical  AI-based predictive control for wind-hydrogen ...
# 311    empirical              Machine learning in injection molding
# 429    empirical                       Daily streamflow forecasting
# 453    empirical                          Forest biomass prediction
# 538    empirical                   Public opinion on climate change
# 678    empirical  Machine learning for drought resilience in agr...
# 733    empirical                        AI and ecological footprint
#
#                                broader_category  \
# 3    Resource prediction and quality management
# 20                         Supply Chain and LCA
# 96                     Psychology and education
# 110  Resource prediction and quality management
# 120  Resource prediction and quality management
# 179                   Health, equity and gender
# 215  Resource prediction and quality management
# 311                        Supply chain and LCA
# 429  Resource prediction and quality management
# 453  Resource prediction and quality management
# 538                   Health, equity and gender
# 678        Risk, security and crisis management
# 733          Pollution and ecological footprint
#
#                                               abstract algorithms  \
# 3    Renewable energy sources are essential paths t...    various
# 20   Energy consumption of buildings accounts for a...    various
# 96   Background. Cardiovascular disease (CVD) annua...    various
# 110  Energy consumption in buildings is increasing ...    various
# 120  Water is involved, directly or indirectly, wit...    various
# 179  The evolution of the Internet of Things, cloud...    various
# 215  Integrating renewable energy into power grids ...    various
# 311  With sustainable growth highlighted as a key t...    various
# 429  Groundwater quality appraisal is one of the mo...    various
# 453  Aboveground biomass (AGB) and carbon uptake of...    various
# 538  Climate change (CC) is a topical issue of prof...    various
# 678  Drought conditions pose significant challenges...    various
# 733  This article explores the impact of artificial...    various
#
#     algorithm_name  ai_type
# 3          various  various
# 20         various  various
# 96         various  various
# 110        various  various
# 120        various  various
# 179        various  various
# 215        various  various
# 311        various  various
# 429        various  various
# 453        various  various
# 538        various  various
# 678        various  various
# 733        various  various
